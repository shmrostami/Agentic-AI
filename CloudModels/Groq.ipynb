# %%
import os
from IPython.display import display, Markdown
from openai import OpenAI

# %%
client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)

response = client.responses.create(
    input="What is the capital of Iran?",
    model="qwen/qwen3-32b",
)
display(Markdown(response.output_text))
# Out:
# The capital of Iran is **Tehran**.
#
# **Key Points About Tehran:**
# 1. **Largest City:** It is Iran's most populous city and the central hub of political, cultural, and economic activity.
# 2. **Geography:** Located in northern Iran, near the foothills of the Alborz Mountains, close to the Caspian Sea.
# 3. **History:** A historic city with significant landmarks like the Golestan Palace (UNESCO World Heritage Site), the Tehran Grand Bazaar, and the Milad Tower.
# 4. **Government and Politics:** Hosts the Iranian government, including the Supreme Leader's office and key institutions.
# 5. **Modern and Traditional Mix:** Known for its blend of ancient sites (e.g., Nasir al-Mulk Mosque) and modern developments.
#
# Tehran is **not** often confused with other notable Iranian cities like Isfahan, Shiraz, or Yazd, which are famed for their own historical and cultural significance but are not the capital.

# %%
available_models = [model for model in client.models.list()]

for model in available_models:
    print(model.id)
# Out:
# moonshotai/kimi-k2-instruct-0905
# meta-llama/llama-prompt-guard-2-22m
# moonshotai/kimi-k2-instruct
# groq/compound
# meta-llama/llama-4-scout-17b-16e-instruct
# canopylabs/orpheus-arabic-saudi
# llama-3.3-70b-versatile
# groq/compound-mini
# llama-3.1-8b-instant
# whisper-large-v3
# openai/gpt-oss-120b
# whisper-large-v3-turbo
# openai/gpt-oss-20b
# playai-tts
# canopylabs/orpheus-v1-english
# meta-llama/llama-guard-4-12b
# meta-llama/llama-4-maverick-17b-128e-instruct
# qwen/qwen3-32b
# allam-2-7b
# openai/gpt-oss-safeguard-20b
# meta-llama/llama-prompt-guard-2-86m
# playai-tts-arabic
